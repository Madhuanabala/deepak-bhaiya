# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhuanabala/deepak-bhaiya/blob/classification-models/atom2dcountlazyclassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lazypredict
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 66.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.2/676.2 kB 41.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 14.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier
import warnings
warnings.filterwarnings("ignore")

# --- Dictionary to store results ---
model_results = {}

# --- List of files and labels ---
files = [
    ('/content/Atom2dCount2_Trainset_top10.csv', 'Top 10 Features'),
    ('/content/Atom2dCount2_Trainset_top20.csv', 'Top 20 Features'),
    ('/content/Atom2dCount2_Trainset_top30.csv', 'Top 30 Features')
]

# --- Loop through each dataset ---
for filepath, label in files:
    print(f"\n🔍 Running LazyClassifier on: {label} (WITHOUT SMOTE)")

    # Load dataset
    df = pd.read_csv(filepath)
    df = df.drop('Unnamed: 0', axis=1, errors='ignore')

    X = df.drop(" BioactivityClass", axis=1)
    Y = df[" BioactivityClass"]

    # Train-test split (no SMOTE)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=100)

    # LazyClassifier on original (imbalanced) data
    clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
    models, predictions = clf.fit(X_train, X_test, Y_train, Y_test)

    # Save and print results
    model_results[label] = models
    print(models)

# --- Optional: Save results to CSV ---
for label, df_models in model_results.items():
    filename = label.replace(" ", "_").lower() + "_results_no_smote.csv"
    df_models.to_csv(filename)
    print(f"📁 Saved: {filename}")
# Out:
# 🔍 Running LazyClassifier on: Top 10 Features (WITHOUT SMOTE)
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 99, number of negative: 554
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000142 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 150
# [LightGBM] [Info] Number of data points in the train set: 653, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.151608 -> initscore=-1.722045
# [LightGBM] [Info] Start training from score -1.722045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
